# %%
import pandas as pd

# %%
data = pd.read_csv("staging_data/training_data.csv")

# %%
data.dtypes
# Out:
# PRCP              int64
# SNOW              int64
# SNWD              int64
# TMAX              int64
# TMIN              int64
# year              int64
# quarter           int64
# month             int64
# week              int64
# day_of_year       int64
# is_leap_year      int64
# latitude        float64
# longitude       float64
# elevation       float64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr = data.corr()

# %%
fig, ax = plt.subplots(1,1, figsize=(16,16))
sns.heatmap(corr, vmax=1, vmin=-1, annot=True, ax=ax)
# Out:
# <Axes: >
